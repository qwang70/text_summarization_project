# %%
import matplotlib.pyplot as plt

# %%
x = [32,64,128,256,512]
p = [0.13518518518518517, 0.10599647266313932, 0.0544973544973545, 0.08225308641975308, 0.08536155202821868]
r = [0.05185185185185185, 0.06976410934744268, 0.03776455026455027, 0.03597883597883598, 0.06137566137566137]
f1 = [0.07804115226337445, 0.06849633905189462,0.04208500389709541,0.046841902953014075, 0.06877441640738914]

# %%
plt.plot(x , p, 'r--', label="Recall")
plt.plot(x, r, 'c-', label="Precision")
plt.legend()
plt.xlabel('Embedding Dimension')
plt.savefig("embedding.png")
